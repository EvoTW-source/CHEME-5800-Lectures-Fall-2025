# %% [markdown]
# # L14a: A Crash Course in Networking
# In this lecture, we will cover the basics of computer networking, including key concepts, protocols, and technologies that enable communication between devices over a network.
#
# > __Learning Objectives:__
# >
# > By the end of this lecture, you should be able to:
# > Three learning objectives here.
#
# Let's get started!
# ___

# %% [markdown]
# ## Summary
# One direct summary sentence of the lecture content goes here.
#
# > __Key Takeaways:__
# > Three key takeaways from the lecture content go here.
#
# One direct conclusion sentence of the lecture content goes here.
# ___
